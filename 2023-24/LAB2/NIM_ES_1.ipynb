# %%
import logging
from pprint import pprint, pformat
from collections import namedtuple
import random
from copy import deepcopy
import heapq

logging.basicConfig(level=logging.DEBUG)

logging.debug("hello")
# Out:
# DEBUG:root:hello

# %% [markdown]
# ## The *Nim* and *Nimply* classes

# %%
Nimply = namedtuple("Nimply", "row, num_objects")

# %%
class Nim:
    def __init__(self, num_rows: int, k: int = None) -> None:
        self._rows = [i * 2 + 1 for i in range(num_rows)]
        self._k = k

    def __bool__(self):
        return sum(self._rows) > 0

    def __str__(self):
        return "<" + " ".join(str(_) for _ in self._rows) + ">"

    @property
    def rows(self) -> tuple:
        return tuple(self._rows)

    @property
    def cooked(self) -> dict:
        '''to generate the possible moves for each game'''
        cooky = dict()
        cooky["possible_moves"] = [Nimply(index, obj) for index, item in enumerate(self._rows) for obj in range(1, item + 1)]
        #[Nimply(row=0, num_objects=1), Nimply(row=1, num_objects=1), Nimply(row=1, num_objects=2), ...
        return cooky

    
    def nimming(self, ply: Nimply) -> None:
        row, num_objects = ply
        assert self._rows[row] >= num_objects, "Number of matches to remove more than what available!"
        assert self._k is None or num_objects <= self._k, f"max number(k) you can remove is {self._k}"
        self._rows[row] -= num_objects

# %% [markdown]
# ## Sample (and silly) startegies

# %%
def pure_random(state: Nim) -> Nimply:
    """A completely random move"""
    #selects a random (non empty) row
    row = random.choice([r for r, c in enumerate(state.rows) if c > 0]) 
    #a random number from 1 to the # objects in the above row
    num_objects = random.randint(1, state.rows[row])
    # returns the move tuple
    return Nimply(row, num_objects)


def gabriele(state: Nim) -> Nimply:
    """Pick always the maximum possible number of the lowest row"""
    #generating all possible moves
    possible_moves = [(r, o) for r, c in enumerate(state.rows) for o in range(1, c + 1)]
    print(possible_moves)
    # select the move with highest objects from lowest row 
    return Nimply(*max(possible_moves, key=lambda m: (-m[0], m[1])))

def adaptive(state: Nim) -> Nimply:
    """A strategy that can adapt its parameters"""
    genome = {"love_small": 0.5}

import numpy as np


def nim_sum(state: Nim) -> int:
    tmp = np.array([tuple(int(x) for x in f"{c:032b}") for c in state.rows])
    xor = tmp.sum(axis=0) % 2
    return int("".join(str(_) for _ in xor), base=2)


def analize(raw: Nim) -> dict:
    cooked = dict()
    # The key is each possible move, value is nimsum (xor) of game board after playing this move.
    cooked["possible_moves"] = dict()
    # for all plays
    for ply in (Nimply(r, o) for r, c in enumerate(raw.rows) for o in range(1, c + 1)):
        tmp = deepcopy(raw)
        tmp.nimming(ply)
        cooked["possible_moves"][ply] = nim_sum(tmp)
    return cooked


def optimal(state: Nim) -> Nimply:
    '''a random move among those with non-zero nim-sum - for normal play (the one that last taker wins) optimal play is to finish every move with nimsum of zero'''
    analysis = analize(state)
    logging.debug(f"analysis:\n{pformat(analysis)}")
    #take the moves with nimsum not zero
    spicy_moves = [ply for ply, ns in analysis["possible_moves"].items() if ns != 0]
    # if there are no optimal, take the random one
    if not spicy_moves:
        spicy_moves = list(analysis["possible_moves"].keys())
    ply = random.choice(spicy_moves)
    return ply

# %% [markdown]
# ### The Evolutionary Strategy Class

# %%
class Evolution:
    def __init__(self,state: Nim) -> None:

        # mutation step size
        self._sigma = 0.40
        self._gamesize = 5
        self._k = 20
        self._game = deepcopy(state)
        self._lambda = 100
        # create a random inditial individual
        self._individual = self.initialize_individual()
        # set of tupels (individual,fitness)
        self.pool = list()
        self.pool.append((self.fitness(self._individual),self._individual))


    def initialize_individual(self):
        '''creates a dictionary that values are possible moves and values are random values with the length of possible moves '''
        random_values = [random.random() for _ in range(len(self._game.cooked["possible_moves"]))]
        individual = {key: value for key, value in zip(self._game.cooked["possible_moves"], random_values)}
        individual = self.renormalize(individual)
        ####temporary check
        self.check_individual(individual)
        return individual

    def update_individual(self, game, indiv):
        '''update the individual dict after the game board and possible moves have changed'''
        keys_to_remove = [key for key in indiv.keys() if key not in game.cooked["possible_moves"]]
        for key in keys_to_remove:
            del indiv[key]    
        upd_indiv = self.renormalize(indiv)
        return upd_indiv




    def check_individual(self,indiv):
        '''check whether _individual is a probablility distribution'''
        tolerance = 0.00001
        #print(f"{indiv} and the sum is {sum(indiv.values())}")
        assert abs(sum(indiv.values()) - 1.0) <= tolerance or sum(indiv.values()) == 0, f"the sum of probabilities of this individual is not 1 - it is not a distribution with tolerance of {tolerance}"
        

    def renormalize(self,indiv):
        '''normalizing the indiv dict'''
        total_sum = sum(indiv.values())
        scaling_factor = 1.0 / total_sum if total_sum != 0 else 0
        for key in indiv:
            indiv[key] *= scaling_factor 
        return indiv

    def tweak(self,indiv):
        '''Guassian mutation to a randomly choosen element of a solution'''
        #random select a move among possible moves
        keylist = list(indiv.keys())
        key = np.random.choice(len(keylist),1)
        chosen_key = keylist[key[0]]
        #add/minus a guassian random with sigma variance
        indiv[chosen_key] += np.random.normal(0, self._sigma)
        #make sure changed prob. is not negative
        indiv[chosen_key] = max(indiv[chosen_key], 0)
        #renormalize
        indiv = self.renormalize(indiv)
        self.check_individual(indiv)
        return indiv

    def play(self,game,indiv):
        '''select and return a move based on prob. dist. of the individual passed'''
        game_ply = Nimply(0,0)
        # loop until a valid move is made
        while not game_ply.num_objects:
            keylist = list(indiv.keys())
            #print(list(indiv.values()))
            #select a key based on prob. dist. in values
            if sum(indiv.values()) == 0 :
                # logging.info(f"the sum of prob.s are zero.and the length of it {len(indiv)}. playing the first available move")
                return list(indiv.keys())[0] 
            key = np.random.choice(len(keylist),1,p=list(indiv.values()))
            chosen_key = keylist[key[0]]
            #print(chosen_key)
            game_ply = chosen_key
        #print(f"the move by PLAY is: {game_ply}")   
        return game_ply


    def pure_random(self, state: Nim,individual):
        """A completely random move"""
        #selects a random (non empty) row
        row = random.choice([r for r, c in enumerate(state.rows) if c > 0]) 
        #a random number from 1 to the # objects in the above row
        num_objects = random.randint(1, state.rows[row])
        # returns the move tuple
        return Nimply(row, num_objects)

    def optimal(self, state: Nim,individual) -> Nimply:
        '''a random move among those with non-zero nim-sum - for normal play (the one that last taker wins) optimal play is to finish every move with nimsum of zero'''
        analysis = analize(state)
        #logging.debug(f"analysis:\n{pformat(analysis)}")
        #take the moves with nimsum not zero
        spicy_moves = [ply for ply, ns in analysis["possible_moves"].items() if ns != 0]
        # if there are no optimal, take the random one
        if not spicy_moves:
            spicy_moves = list(analysis["possible_moves"].keys())
        ply = random.choice(spicy_moves)
        return ply




    def fitness(self,indiv):
        '''the fitness of an individual is the number of wins in 100 plays against a benchmark strategy'''
        number_of_plays = 100
       
        benchmark_strategy = self.pure_random
        opponents = {'0':0,'1':0}
        # Player '0' is the ES agent
        strategy = (self.play,benchmark_strategy)
        wins = 0
        total_moves = 0

        for i in range(number_of_plays):
            local_game = Nim(self._gamesize,self._k)
            local_indiv = deepcopy(indiv)
            moves = 0
            players = [0 if p < (number_of_plays/2) else 1 for p in range(number_of_plays)]
            player = players[i]

            while local_game:
                ply = strategy[player](local_game,local_indiv)
                local_game.nimming(ply)
                #update individual
                local_indiv = self.update_individual(local_game,local_indiv)
                #counting the number of moves
                if player == 0:
                    moves += 1
                
                player = 1 - player
            
            opponents[str(player)]+=1
            if player == 0:
                total_moves += moves
        #print(opponents)
        wins = opponents['0']
        #the average moves the agent made in the games it won
        avg_moves = total_moves / wins
        #print(avg_moves)
        # factor to calibrate fitness 
        x = 0.6
        return  x * wins + (1-x) * (number_of_plays/avg_moves)
        #return wins



    def evolve_one_plus_lambda(self,pool):
        '''1 + labmda strategy!'''

        for i in range(10):

            print(pool[0])
            indiv = pool[0]

            # if len(keep) >2: 
            #     keep.sort(key=lambda x:-x[0])
            #     print("inside keep")
            #     #print(keep[-2])
            #     if keep[-2][0] == keep[-1][0]:
            #         rst_indiv = self.initialize_individual()
            #         pool = []
            #         pool.append((-self.fitness(rst_indiv),rst_indiv))


            for i in range(self._lambda):
                new_indiv = self.tweak(indiv[1])
                fitness = self.fitness(new_indiv)
                pool.append((fitness,new_indiv))

            pool.sort(key=lambda x: x[0],reverse=True)
            pool[1:]=[]
    
        print(f"Best fitted individdual found: {pool[0][0]}")

        

logging.basicConfig(level=logging.ERROR)

test = Nim(5,200)
evol = Evolution(test)

evol.evolve_one_plus_lambda(evol.pool)
# Out:
# (31.44123711340206, {Nimply(row=0, num_objects=1): 0.04384496200562994, Nimply(row=1, num_objects=1): 0.043536190909567535, Nimply(row=1, num_objects=2): 0.04668728175085692, Nimply(row=1, num_objects=3): 0.026153259860843023, Nimply(row=2, num_objects=1): 0.01888846415800912, Nimply(row=2, num_objects=2): 0.05601866889379967, Nimply(row=2, num_objects=3): 0.023451384148740966, Nimply(row=2, num_objects=4): 0.05665363347968643, Nimply(row=2, num_objects=5): 0.012532254709644496, Nimply(row=3, num_objects=1): 0.024295847725764624, Nimply(row=3, num_objects=2): 0.021268654097219026, Nimply(row=3, num_objects=3): 0.03526095424775828, Nimply(row=3, num_objects=4): 0.07326238079837563, Nimply(row=3, num_objects=5): 0.04155170785914378, Nimply(row=3, num_objects=6): 0.04094593031905654, Nimply(row=3, num_objects=7): 0.04548232561253695, Nimply(row=4, num_objects=1): 0.011526533505740797, Nimply(row=4, num_objects=2): 0.03051607178867517, Nimply(row=4, num_objects=3): 0.038863171879691676, Nimply(row=4, num_objects=4): 0.04045278250442419, Nimply(row=4, num_objects=5): 0.05340948597064228, Nimply(row=4, num_objects=6): 0.03824593599204865, Nimply(row=4, num_objects=7): 0.06338694134171861, Nimply(row=4, num_objects=8): 0.058072345187703656, Nimply(row=4, num_objects=9): 0.055692831252722064})
# (44.6251497005988, {Nimply(row=0, num_objects=1): 1.3629464868246719e-06, Nimply(row=1, num_objects=1): 0.19945036403375688, Nimply(row=1, num_objects=2): 0.0, Nimply(row=1, num_objects=3): 7.993425526481304e-06, Nimply(row=2, num_objects=1): 0.0, Nimply(row=2, num_objects=2): 0.0, Nimply(row=2, num_objects=3): 0.00025650721039002073, Nimply(row=2, num_objects=4): 0.0, Nimply(row=2, num_objects=5): 0.03150677971147272, Nimply(row=3, num_objects=1): 0.0008718807814188067, Nimply(row=3, num_objects=2): 0.011191937459996177, Nimply(row=3, num_objects=3): 0.3905136409322141, Nimply(row=3, num_objects=4): 0.0, Nimply(row=3, num_objects=5): 0.0, Nimply(row=3, num_objects=6): 0.0, Nimply(row=3, num_objects=7): 1.4138448996320997e-06, Nimply(row=4, num_objects=1): 0.0, Nimply(row=4, num_objects=2): 0.1834353454115114, Nimply(row=4, num_objects=3): 0.0, Nimply(row=4, num_objects=4): 0.1114964158568617, Nimply(row=4, num_objects=5): 0.018641288472185224, Nimply(row=4, num_objects=6): 0.05262506991328018, Nimply(row=4, num_objects=7): 0.0, Nimply(row=4, num_objects=8): 0.0, Nimply(row=4, num_objects=9): 0.0})
# (49.775342465753425, {Nimply(row=0, num_objects=1): 0.11704196492313927, Nimply(row=1, num_objects=1): 0.07174395781455986, Nimply(row=1, num_objects=2): 0.0013092359125523767, Nimply(row=1, num_objects=3): 0.0, Nimply(row=2, num_objects=1): 0.0, Nimply(row=2, num_objects=2): 0.02853755121383573, Nimply(row=2, num_objects=3): 0.0, Nimply(row=2, num_objects=4): 0.05964464929411806, Nimply(row=2, num_objects=5): 0.0, Nimply(row=3, num_objects=1): 0.1891033476338649, Nimply(row=3, num_objects=2): 0.0, Nimply(row=3, num_objects=3): 0.09474424939941667, Nimply(row=3, num_objects=4): 0.0, Nimply(row=3, num_objects=5): 0.0, Nimply(row=3, num_objects=6): 0.03522635802377874, Nimply(row=3, num_objects=7): 0.0, Nimply(row=4, num_objects=1): 0.017290761651291963, Nimply(row=4, num_objects=2): 0.031027066480777642, Nimply(row=4, num_objects=3): 0.0, Nimply(row=4, num_objects=4): 0.0, Nimply(row=4, num_objects=5): 0.20427673834570576, Nimply(row=4, num_objects=6): 0.13029611009182865, Nimply(row=4, num_objects=7): 0.0, Nimply(row=4, num_objects=8): 0.0, Nimply(row=4, num_objects=9): 0.019758009215130237})
# (49.775342465753425, {Nimply(row=0, num_objects=1): 0.0, Nimply(row=1, num_objects=1): 0.37839432054535266, Nimply(row=1, num_objects=2): 0.0, Nimply(row=1, num_objects=3): 0.00020908177661486417, Nimply(row=2, num_objects=1): 0.0, Nimply(row=2, num_objects=2): 0.0023812477741515653, Nimply(row=2, num_objects=3): 0.029874021765551834, Nimply(row=2, num_objects=4): 0.00014165074224120234, Nimply(row=2, num_objects=5): 0.003388362952790202, Nimply(row=3, num_objects=1): 0.0, Nimply(row=3, num_objects=2): 0.0, Nimply(row=3, num_objects=3): 0.08450042381460418, Nimply(row=3, num_objects=4): 0.0, Nimply(row=3, num_objects=5): 0.03292705909290032, Nimply(row=3, num_objects=6): 0.039734520404330266, Nimply(row=3, num_objects=7): 8.906191146922522e-07, Nimply(row=4, num_objects=1): 0.21329784973969926, Nimply(row=4, num_objects=2): 0.0, Nimply(row=4, num_objects=3): 0.0659260111408291, Nimply(row=4, num_objects=4): 0.017071670026080222, Nimply(row=4, num_objects=5): 0.0, Nimply(row=4, num_objects=6): 0.04711744414621066, Nimply(row=4, num_objects=7): 0.0, Nimply(row=4, num_objects=8): 0.0, Nimply(row=4, num_objects=9): 0.08503544545952915})
# (49.775342465753425, {Nimply(row=0, num_objects=1): 0.0, Nimply(row=1, num_objects=1): 0.2972058513482597, Nimply(row=1, num_objects=2): 0.06332436726464996, Nimply(row=1, num_objects=3): 0.03218859645848971, Nimply(row=2, num_objects=1): 0.0, Nimply(row=2, num_objects=2): 0.00046941988668671965, Nimply(row=2, num_objects=3): 0.003870954216235932, Nimply(row=2, num_objects=4): 0.006373863005390794, Nimply(row=2, num_objects=5): 0.07766107350101395, Nimply(row=3, num_objects=1): 0.0, Nimply(row=3, num_objects=2): 0.0, Nimply(row=3, num_objects=3): 0.0, Nimply(row=3, num_objects=4): 0.0, Nimply(row=3, num_objects=5): 0.01551824940068974, Nimply(row=3, num_objects=6): 0.15625697333311017, Nimply(row=3, num_objects=7): 0.0, Nimply(row=4, num_objects=1): 5.478930790419766e-05, Nimply(row=4, num_objects=2): 0.0, Nimply(row=4, num_objects=3): 0.017546604916272482, Nimply(row=4, num_objects=4): 0.01638893769809101, Nimply(row=4, num_objects=5): 0.04289088573879643, Nimply(row=4, num_objects=6): 0.11749021869908954, Nimply(row=4, num_objects=7): 0.06629621001902365, Nimply(row=4, num_objects=8): 0.0, Nimply(row=4, num_objects=9): 0.08646300520629575})
# (52.07195467422096, {Nimply(row=0, num_objects=1): 0.0009425548231325132, Nimply(row=1, num_objects=1): 0.13271908250643039, Nimply(row=1, num_objects=2): 0.17681784139272186, Nimply(row=1, num_objects=3): 0.0, Nimply(row=2, num_objects=1): 0.0, Nimply(row=2, num_objects=2): 7.576381350689996e-05, Nimply(row=2, num_objects=3): 0.0, Nimply(row=2, num_objects=4): 0.0, Nimply(row=2, num_objects=5): 0.003968681950010156, Nimply(row=3, num_objects=1): 0.2068315759773426, Nimply(row=3, num_objects=2): 0.00366899874293785, Nimply(row=3, num_objects=3): 0.0, Nimply(row=3, num_objects=4): 0.0, Nimply(row=3, num_objects=5): 0.026705310600930503, Nimply(row=3, num_objects=6): 0.0025258097537352924, Nimply(row=3, num_objects=7): 0.020717450253436524, Nimply(row=4, num_objects=1): 0.29079885659963045, Nimply(row=4, num_objects=2): 0.0, Nimply(row=4, num_objects=3): 0.003495363634330303, Nimply(row=4, num_objects=4): 0.0523707544686976, Nimply(row=4, num_objects=5): 0.0, Nimply(row=4, num_objects=6): 0.02715786405090107, Nimply(row=4, num_objects=7): 0.0, Nimply(row=4, num_objects=8): 0.05120409143225619, Nimply(row=4, num_objects=9): 0.0})
# (52.07195467422096, {Nimply(row=0, num_objects=1): 0.02059951087807369, Nimply(row=1, num_objects=1): 4.8202077933810925e-05, Nimply(row=1, num_objects=2): 0.01838382671466762, Nimply(row=1, num_objects=3): 0.0020343661058743532, Nimply(row=2, num_objects=1): 0.0, Nimply(row=2, num_objects=2): 0.0, Nimply(row=2, num_objects=3): 0.0, Nimply(row=2, num_objects=4): 0.32688969543376206, Nimply(row=2, num_objects=5): 0.0, Nimply(row=3, num_objects=1): 0.0, Nimply(row=3, num_objects=2): 0.009045469770665846, Nimply(row=3, num_objects=3): 0.14828512889646686, Nimply(row=3, num_objects=4): 0.0, Nimply(row=3, num_objects=5): 0.0, Nimply(row=3, num_objects=6): 0.0, Nimply(row=3, num_objects=7): 0.07516125719577173, Nimply(row=4, num_objects=1): 0.0029363399723079313, Nimply(row=4, num_objects=2): 0.0, Nimply(row=4, num_objects=3): 0.02557983873034094, Nimply(row=4, num_objects=4): 0.0, Nimply(row=4, num_objects=5): 0.0038041214567839676, Nimply(row=4, num_objects=6): 0.14123938829412658, Nimply(row=4, num_objects=7): 0.11632593168440514, Nimply(row=4, num_objects=8): 0.0, Nimply(row=4, num_objects=9): 0.10966692278881938})
# (52.07195467422096, {Nimply(row=0, num_objects=1): 3.6319631894181385e-05, Nimply(row=1, num_objects=1): 0.0, Nimply(row=1, num_objects=2): 0.0, Nimply(row=1, num_objects=3): 0.0, Nimply(row=2, num_objects=1): 0.3108079595453826, Nimply(row=2, num_objects=2): 0.10445920057345691, Nimply(row=2, num_objects=3): 0.0, Nimply(row=2, num_objects=4): 0.09943054858886312, Nimply(row=2, num_objects=5): 0.0, Nimply(row=3, num_objects=1): 0.00422438198905792, Nimply(row=3, num_objects=2): 0.02166727301976949, Nimply(row=3, num_objects=3): 0.0, Nimply(row=3, num_objects=4): 0.0, Nimply(row=3, num_objects=5): 0.0, Nimply(row=3, num_objects=6): 0.18632896200387072, Nimply(row=3, num_objects=7): 0.0, Nimply(row=4, num_objects=1): 0.0, Nimply(row=4, num_objects=2): 0.0, Nimply(row=4, num_objects=3): 0.0, Nimply(row=4, num_objects=4): 0.0, Nimply(row=4, num_objects=5): 0.0, Nimply(row=4, num_objects=6): 0.06255240522511926, Nimply(row=4, num_objects=7): 0.0, Nimply(row=4, num_objects=8): 0.21049294942258573, Nimply(row=4, num_objects=9): 0.0})
# (52.07195467422096, {Nimply(row=0, num_objects=1): 0.0, Nimply(row=1, num_objects=1): 0.0, Nimply(row=1, num_objects=2): 0.0, Nimply(row=1, num_objects=3): 0.0, Nimply(row=2, num_objects=1): 0.06931735408772227, Nimply(row=2, num_objects=2): 0.1115819072026305, Nimply(row=2, num_objects=3): 0.0, Nimply(row=2, num_objects=4): 0.0, Nimply(row=2, num_objects=5): 0.0067106575099608184, Nimply(row=3, num_objects=1): 0.016220426125073448, Nimply(row=3, num_objects=2): 0.3748998132749212, Nimply(row=3, num_objects=3): 0.024868415605213565, Nimply(row=3, num_objects=4): 0.0, Nimply(row=3, num_objects=5): 0.0, Nimply(row=3, num_objects=6): 0.05395053501352994, Nimply(row=3, num_objects=7): 0.04458788319722177, Nimply(row=4, num_objects=1): 0.08227087930132054, Nimply(row=4, num_objects=2): 0.0, Nimply(row=4, num_objects=3): 0.007440289576347832, Nimply(row=4, num_objects=4): 0.010276091411489295, Nimply(row=4, num_objects=5): 0.0, Nimply(row=4, num_objects=6): 0.1978757476945689, Nimply(row=4, num_objects=7): 0.0, Nimply(row=4, num_objects=8): 0.0, Nimply(row=4, num_objects=9): 0.0})
# (52.07195467422096, {Nimply(row=0, num_objects=1): 0.001475190009470727, Nimply(row=1, num_objects=1): 0.09732623011033521, Nimply(row=1, num_objects=2): 0.0, Nimply(row=1, num_objects=3): 0.1806035676723572, Nimply(row=2, num_objects=1): 0.0, Nimply(row=2, num_objects=2): 0.0, Nimply(row=2, num_objects=3): 0.1184156877368688, Nimply(row=2, num_objects=4): 0.02489822208149788, Nimply(row=2, num_objects=5): 0.0185482437864784, Nimply(row=3, num_objects=1): 0.0, Nimply(row=3, num_objects=2): 0.0, Nimply(row=3, num_objects=3): 0.03638636473296878, Nimply(row=3, num_objects=4): 0.03699167725086734, Nimply(row=3, num_objects=5): 0.24700211262212107, Nimply(row=3, num_objects=6): 0.0, Nimply(row=3, num_objects=7): 0.008832130227706387, Nimply(row=4, num_objects=1): 0.0, Nimply(row=4, num_objects=2): 0.0, Nimply(row=4, num_objects=3): 0.0, Nimply(row=4, num_objects=4): 0.0, Nimply(row=4, num_objects=5): 0.0, Nimply(row=4, num_objects=6): 0.0, Nimply(row=4, num_objects=7): 0.0, Nimply(row=4, num_objects=8): 0.10262056227167224, Nimply(row=4, num_objects=9): 0.12690001149765595})
# 52.07195467422096
